# %%
import pandas as pd

# %%
data_df = pd.read_csv("alcohol consumption.csv")
data_df.head()
# Out:
#    Year Locationabbr Locationdesc                Class                Topic  \
# 0  2014           AL      Alabama  Alcohol Consumption  Alcohol Consumption
# 1  2014           AK       Alaska  Alcohol Consumption  Alcohol Consumption
# 2  2014           AZ      Arizona  Alcohol Consumption  Alcohol Consumption
# 3  2014           AR     Arkansas  Alcohol Consumption  Alcohol Consumption
# 4  2014           CA   California  Alcohol Consumption  Alcohol Consumption
#
#                                             Question Response Break_Out  \
# 0  Adults who have had at least one drink of alco...      Yes   Overall
# 1  Adults who have had at least one drink of alco...      Yes   Overall
# 2  Adults who have had at least one drink of alco...      Yes   Overall
# 3  Adults who have had at least one drink of alco...      Yes   Overall
# 4  Adults who have had at least one drink of alco...      Yes   Overall
#
# ...

# %%
data2_df = pd.read_csv("current smoker status.csv")
data2_df.head()
# Out:
#    Year Locationabbr Locationdesc        Class                  Topic  \
# 0  2014           AL      Alabama  Tobacco Use  Current Smoker Status
# 1  2014           AK       Alaska  Tobacco Use  Current Smoker Status
# 2  2014           AZ      Arizona  Tobacco Use  Current Smoker Status
# 3  2014           AR     Arkansas  Tobacco Use  Current Smoker Status
# 4  2014           CA   California  Tobacco Use  Current Smoker Status
#
#                                             Question Response Break_Out  \
# 0  Adults who are current smokers (variable calcu...      Yes   Overall
# 1  Adults who are current smokers (variable calcu...      Yes   Overall
# 2  Adults who are current smokers (variable calcu...      Yes   Overall
# 3  Adults who are current smokers (variable calcu...      Yes   Overall
# 4  Adults who are current smokers (variable calcu...      Yes   Overall
#
#   Break_Out_Category Sample_Size                    ...                      \
# ...
